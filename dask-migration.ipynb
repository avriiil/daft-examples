# %% [markdown]
# # Dask Migration Guide

# %%
import dask.dataframe as dd
import dask
dask.__version__
# Out:
# /var/folders/ky/bqjn_gxn1xv0cn_8q5xvp3q40000gn/T/ipykernel_2531/2206678657.py:1: DeprecationWarning: The current Dask DataFrame implementation is deprecated.
# In a future release, Dask DataFrame will use a new implementation that
# contains several improvements including a logical query planning.
# The user-facing DataFrame API will remain unchanged.
#
# The new implementation is already available and can be enabled by
# installing the dask-expr library:
#
#     $ pip install dask-expr
#
# and turning the query planning option on:
#
#     >>> import dask
#     >>> dask.config.set({'dataframe.query-planning': True})
#     >>> import dask.dataframe as dd
#
# API documentation for the new implementation is available at
# https://docs.dask.org/en/stable/dask-expr-api.html
#
# Any feedback can be reported on the Dask issue tracker
# https://github.com/dask/dask/issues
#
# To disable this warning in the future, set dask config:
#
#     # via Python
#     >>> dask.config.set({'dataframe.query-planning-warning': False})
#
#     # via CLI
#     dask config set dataframe.query-planning-warning False
#
#
#   import dask.dataframe as dd
# '2024.2.1'

# %%
# load Parquet file with 783 million row 

ddf = dd.read_parquet(
    "s3://coiled-datasets/uber-lyft-tlc/",
    filesystem='pyarrow',
)
ddf.head()
# Out:
#                     hvfhs_license_num dispatching_base_num  \
# __null_dask_index__
# 0                              HV0003               B02867
# 1                              HV0003               B02879
# 2                              HV0005               B02510
# 3                              HV0005               B02510
# 4                              HV0005               B02510
#
#                     originating_base_num    request_datetime  \
# __null_dask_index__
# 0                                 B02867 2019-02-01 00:01:26
# 1                                 B02879 2019-02-01 00:26:08
# 2                                   <NA> 2019-02-01 00:48:58
# 3                                   <NA> 2019-02-01 00:02:15
# 4                                   <NA> 2019-02-01 00:06:17
#
#                       on_scene_datetime     pickup_datetime  \
# __null_dask_index__
# 0                   2019-02-01 00:02:55 2019-02-01 00:05:18
# 1                   2019-02-01 00:41:29 2019-02-01 00:41:29
# 2                                   NaT 2019-02-01 00:51:34
# 3                                   NaT 2019-02-01 00:03:51
# 4                                   NaT 2019-02-01 00:09:44
#
#                        dropoff_datetime  PULocationID  DOLocationID  \
# __null_dask_index__
# 0                   2019-02-01 00:14:57           245           251
# 1                   2019-02-01 00:49:39           216           197
# 2                   2019-02-01 01:28:29           261           234
# 3                   2019-02-01 00:07:16            87            87
# 4                   2019-02-01 00:39:56            87           198
#
#                      trip_miles  ...  sales_tax  congestion_surcharge  \
# __null_dask_index__              ...
# 0                          2.45  ...       0.83                   0.0
# 1                          1.71  ...       0.70                   0.0
# 2                          5.01  ...       3.99                   0.0
# 3                          0.34  ...       0.64                   0.0
# 4                          6.84  ...       2.16                   0.0
#
#                      airport_fee  tips  driver_pay  shared_request_flag  \
# __null_dask_index__
# 0                            NaN   0.0    7.480000                    Y
# 1                            NaN   2.0    7.930000                    N
# 2                            NaN   0.0   35.970001                    N
# 3                            NaN   3.0    5.390000                    N
# 4                            NaN   4.0   17.070000                    N
#
#                      shared_match_flag  access_a_ride_flag  wav_request_flag  \
# __null_dask_index__
# 0                                    N                   N                 N
# 1                                    N                   N                 N
# 2                                    Y                   N                 N
# 3                                    Y                   N                 N
# 4                                    Y                   N                 N
#
#                     wav_match_flag
# __null_dask_index__
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
# [5 rows x 24 columns]

# %%
len(ddf)
# Out:
# 783431901

# %%
io_config = IOConfig(s3=S3Config(anonymous=True))

df = daft.read_parquet(
    "s3://coiled-datasets/uber-lyft-tlc/",
    io_config=io_config,
)
df.show()
# Out:
# ╭─────────────────┬─────────────────┬─────────────────┬─────────────┬────────────────┬────────────────┬────────────────╮
# │ hvfhs_license_n ┆ dispatching_bas ┆ originating_bas ┆      …      ┆ wav_request_fl ┆ wav_match_flag ┆ __null_dask_in │
# │ um              ┆ e_num           ┆ e_num           ┆             ┆ ag             ┆ ---            ┆ dex__          │
# │ ---             ┆ ---             ┆ ---             ┆ (19 hidden) ┆ ---            ┆ Utf8           ┆ ---            │
# │ Utf8            ┆ Utf8            ┆ Utf8            ┆             ┆ Utf8           ┆                ┆ Int64          │
# ╞═════════════════╪═════════════════╪═════════════════╪═════════════╪════════════════╪════════════════╪════════════════╡
# │ HV0003          ┆ B02867          ┆ B02867          ┆ …           ┆ N              ┆ None           ┆ 0              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02879          ┆ B02879          ┆ …           ┆ N              ┆ None           ┆ 1              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 2              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 3              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 4              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ …               ┆ …               ┆ …               ┆ …           ┆ …              ┆ …              ┆ …              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02764          ┆ B02764          ┆ …           ┆ N              ┆ None           ┆ 1068598        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02764          ┆ B02764          ┆ …           ┆ N              ┆ None           ┆ 1068599        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ N              ┆ 1068600        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ N              ┆ 1068601        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02872          ┆ B02872          ┆ …           ┆ N              ┆ None           ┆ 1068602        │
# ╰─────────────────┴─────────────────┴─────────────────┴─────────────┴────────────────┴────────────────┴────────────────╯
#
# (Showing first 8 rows)

# %%
ddf = dd.read_parquet(
"s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
storage_options={"anon": True},
)
ddf.head()
# Out:
#   tpep_pickup_datetime  VendorID tpep_dropoff_datetime  passenger_count  \
# 0  2015-01-01 00:00:00         1   2015-01-01 00:11:26                5
# 1  2015-01-01 00:00:00         2   2015-01-01 00:00:00                3
# 2  2015-01-01 00:00:00         2   2015-01-01 00:00:00                1
# 3  2015-01-01 00:00:01         1   2015-01-01 00:03:49                1
# 4  2015-01-01 00:00:03         2   2015-01-01 00:21:48                2
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           4.00        -73.971436        40.760201           1
# 1           1.56        -74.001320        40.729057           1
# 2           1.68        -73.991547        40.750069           1
# 3           0.80        -73.860847        40.757294           1
# 4           2.57        -73.969017        40.754269           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.921181         40.768269             2
# 1                  N         -74.010208         40.719662             1
# 2                  N           0.000000          0.000000             2
# 3                  N         -73.868111         40.752285             2
# 4                  N         -73.994133         40.761600             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         13.5    0.5      0.5         0.0           0.0
# 1          7.5    0.5      0.5         0.0           0.0
# 2         10.0    0.0      0.5         0.0           0.0
# 3          5.0    0.5      0.5         0.0           0.0
# 4         14.5    0.5      0.5         0.0           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.0          14.5
# 1                    0.3           8.8
# 2                    0.3          10.8
# 3                    0.0           6.3
# 4                    0.3          15.8

# %%
import daft
from daft.io import IOConfig, S3Config
daft.__version__
# Out:
# '0.2.21'

# %%
io_config = IOConfig(s3=S3Config(anonymous=True))

df = daft.read_parquet(
    "s3://dask-data/nyc-taxi/nyc-2015.parquet/part.*.parquet",
    io_config=io_config,
)
df.show()
# Out:
# ScanWithTask-LocalLimit [Stage:6]:   0%|                                                          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Reading Data

# %%
# read 783 million row Parquet file
ddf = dd.read_parquet(
    "s3://coiled-datasets/uber-lyft-tlc/",
    filesystem='pyarrow',
)
ddf.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B02867               B02867
# 1            HV0003               B02879               B02879
# 2            HV0005               B02510                 <NA>
# 3            HV0005               B02510                 <NA>
# 4            HV0005               B02510                 <NA>
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2019-02-01 00:01:26 2019-02-01 00:02:55 2019-02-01 00:05:18
# 1 2019-02-01 00:26:08 2019-02-01 00:41:29 2019-02-01 00:41:29
# 2 2019-02-01 00:48:58                 NaT 2019-02-01 00:51:34
# 3 2019-02-01 00:02:15                 NaT 2019-02-01 00:03:51
# 4 2019-02-01 00:06:17                 NaT 2019-02-01 00:09:44
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  sales_tax  \
# 0 2019-02-01 00:14:57           245           251        2.45  ...       0.83
# 1 2019-02-01 00:49:39           216           197        1.71  ...       0.70
# 2 2019-02-01 01:28:29           261           234        5.01  ...       3.99
# 3 2019-02-01 00:07:16            87            87        0.34  ...       0.64
# 4 2019-02-01 00:39:56            87           198        6.84  ...       2.16
#
#    congestion_surcharge  airport_fee  tips  driver_pay  shared_request_flag  \
# 0                   0.0          NaN   0.0    7.480000                    Y
# 1                   0.0          NaN   2.0    7.930000                    N
# 2                   0.0          NaN   0.0   35.970001                    N
# 3                   0.0          NaN   3.0    5.390000                    N
# 4                   0.0          NaN   4.0   17.070000                    N
#
#    shared_match_flag  access_a_ride_flag  wav_request_flag wav_match_flag
# 0                  N                   N                 N            NaN
# 1                  N                   N                 N            NaN
# 2                  Y                   N                 N            NaN
# 3                  Y                   N                 N            NaN
# 4                  Y                   N                 N            NaN
#
# [5 rows x 24 columns]

# %%
# 720 partitions
ddf
# Out:
# Dask DataFrame Structure:
#                 hvfhs_license_num dispatching_base_num originating_base_num request_datetime on_scene_datetime pickup_datetime dropoff_datetime PULocationID DOLocationID trip_miles trip_time base_passenger_fare    tolls      bcf sales_tax congestion_surcharge airport_fee     tips driver_pay shared_request_flag  shared_match_flag access_a_ride_flag   wav_request_flag     wav_match_flag
# npartitions=720
#                            string               string               string   datetime64[us]    datetime64[us]  datetime64[us]   datetime64[us]        int32        int32    float32     int32             float32  float32  float32   float32              float32     float32  float32    float32   category[unknown]  category[unknown]  category[unknown]  category[unknown]  category[unknown]
#                               ...                  ...                  ...              ...               ...             ...              ...          ...          ...        ...       ...                 ...      ...      ...       ...                  ...         ...      ...        ...                 ...                ...                ...                ...                ...
# ...                           ...                  ...                  ...              ...               ...             ...              ...          ...          ...        ...       ...                 ...      ...      ...       ...                  ...         ...      ...        ...                 ...                ...                ...                ...                ...
#                               ...                  ...                  ...              ...               ...             ...              ...          ...          ...        ...       ...                 ...      ...      ...       ...                  ...         ...      ...        ...                 ...                ...                ...                ...                ...
#                               ...                  ...                  ...              ...               ...             ...              ...          ...          ...        ...       ...                 ...      ...      ...       ...                  ...         ...      ...        ...                 ...                ...                ...                ...                ...
# Dask Name: read-parquet, 1 graph layer

# %%
# dask uses an index
ddf.index
# Out:
# Dask Index Structure:
# npartitions=720
#     int64
#       ...
#     ...
#       ...
#       ...
# dtype: int64
# Dask Name: read-parquet-index, 2 graph layers

# %%
# daft predicate filtering
# note pandas-like selection
ddf[ddf.trip_miles < 3].head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B02867               B02867
# 1            HV0003               B02879               B02879
# 3            HV0005               B02510                 <NA>
# 5            HV0005               B02510                 <NA>
# 8            HV0003               B02867               B02867
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2019-02-01 00:01:26 2019-02-01 00:02:55 2019-02-01 00:05:18
# 1 2019-02-01 00:26:08 2019-02-01 00:41:29 2019-02-01 00:41:29
# 3 2019-02-01 00:02:15                 NaT 2019-02-01 00:03:51
# 5 2019-02-01 00:56:01                 NaT 2019-02-01 00:59:55
# 8 2019-02-01 00:00:35 2019-02-01 00:09:33 2019-02-01 00:10:48
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  sales_tax  \
# 0 2019-02-01 00:14:57           245           251        2.45  ...       0.83
# 1 2019-02-01 00:49:39           216           197        1.71  ...       0.70
# 3 2019-02-01 00:07:16            87            87        0.34  ...       0.64
# 5 2019-02-01 01:06:28           198           198        1.11  ...       0.51
# 8 2019-02-01 00:20:23           226           260        1.59  ...       0.62
#
#    congestion_surcharge  airport_fee  tips  driver_pay  shared_request_flag  \
# 0                   0.0          NaN   0.0        7.48                    Y
# 1                   0.0          NaN   2.0        7.93                    N
# 3                   0.0          NaN   3.0        5.39                    N
# 5                   0.0          NaN   0.0        0.00                    Y
# 8                   0.0          NaN   0.0        6.51                    Y
#
#    shared_match_flag  access_a_ride_flag  wav_request_flag wav_match_flag
# 0                  N                   N                 N            NaN
# 1                  N                   N                 N            NaN
# 3                  Y                   N                 N            NaN
# 5                  Y                   N                 N            NaN
# 8                  N                   N                 N            NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# For this computation, Dask loads in all of the data and only applies the filter afterwards. It does not have Query Optimization. NB: working on it but at the moment unstable. Also Dask is pure Python so query engine will not have the C/C++ performance of Rust.
#
# Daft's Query Optimization means that the filter is pushed to the read_parquet call, which means that Daft knows it only needs to look at the `trip_miles` column, instead of reading all 24 columns.

# %%
import daft
from daft.io import IOConfig, S3Config

# %%
# df = daft.read_parquet("yellow_tripdata_2023-12.parquet")
# df.show()

io_config = IOConfig(s3=S3Config(anonymous=True))

df = daft.read_parquet(
    "s3://coiled-datasets/uber-lyft-tlc/",
    io_config=io_config,
)
df.show()
# Out:
# ╭─────────────────┬─────────────────┬─────────────────┬─────────────┬────────────────┬────────────────┬────────────────╮
# │ hvfhs_license_n ┆ dispatching_bas ┆ originating_bas ┆      …      ┆ wav_request_fl ┆ wav_match_flag ┆ __null_dask_in │
# │ um              ┆ e_num           ┆ e_num           ┆             ┆ ag             ┆ ---            ┆ dex__          │
# │ ---             ┆ ---             ┆ ---             ┆ (19 hidden) ┆ ---            ┆ Utf8           ┆ ---            │
# │ Utf8            ┆ Utf8            ┆ Utf8            ┆             ┆ Utf8           ┆                ┆ Int64          │
# ╞═════════════════╪═════════════════╪═════════════════╪═════════════╪════════════════╪════════════════╪════════════════╡
# │ HV0003          ┆ B02867          ┆ B02867          ┆ …           ┆ N              ┆ None           ┆ 0              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02879          ┆ B02879          ┆ …           ┆ N              ┆ None           ┆ 1              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 2              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 3              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 4              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ …               ┆ …               ┆ …               ┆ …           ┆ …              ┆ …              ┆ …              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02764          ┆ B02764          ┆ …           ┆ N              ┆ None           ┆ 1068598        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02764          ┆ B02764          ┆ …           ┆ N              ┆ None           ┆ 1068599        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ N              ┆ 1068600        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ N              ┆ 1068601        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02872          ┆ B02872          ┆ …           ┆ N              ┆ None           ┆ 1068602        │
# ╰─────────────────┴─────────────────┴─────────────────┴─────────────┴────────────────┴────────────────┴────────────────╯
#
# (Showing first 8 rows)

# %%
# predicate filtering
df.where(daft.col("trip_miles") < 3).show()
# Out:
# ╭─────────────────┬─────────────────┬─────────────────┬─────────────┬────────────────┬────────────────┬────────────────╮
# │ hvfhs_license_n ┆ dispatching_bas ┆ originating_bas ┆      …      ┆ wav_request_fl ┆ wav_match_flag ┆ __null_dask_in │
# │ um              ┆ e_num           ┆ e_num           ┆             ┆ ag             ┆ ---            ┆ dex__          │
# │ ---             ┆ ---             ┆ ---             ┆ (19 hidden) ┆ ---            ┆ Utf8           ┆ ---            │
# │ Utf8            ┆ Utf8            ┆ Utf8            ┆             ┆ Utf8           ┆                ┆ Int64          │
# ╞═════════════════╪═════════════════╪═════════════════╪═════════════╪════════════════╪════════════════╪════════════════╡
# │ HV0003          ┆ B02867          ┆ B02867          ┆ …           ┆ N              ┆ None           ┆ 0              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02879          ┆ B02879          ┆ …           ┆ N              ┆ None           ┆ 1              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 3              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ None           ┆ 5              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02867          ┆ B02867          ┆ …           ┆ N              ┆ None           ┆ 8              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ …               ┆ …               ┆ …               ┆ …           ┆ …              ┆ …              ┆ …              │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02872          ┆ B02872          ┆ …           ┆ N              ┆ None           ┆ 1068602        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02872          ┆ B02872          ┆ …           ┆ N              ┆ None           ┆ 1068603        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02879          ┆ B02879          ┆ …           ┆ N              ┆ None           ┆ 1068605        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0003          ┆ B02617          ┆ B02617          ┆ …           ┆ N              ┆ None           ┆ 1068606        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ HV0005          ┆ B02510          ┆ None            ┆ …           ┆ N              ┆ N              ┆ 1068607        │
# ╰─────────────────┴─────────────────┴─────────────────┴─────────────┴────────────────┴────────────────┴────────────────╯
#
# (Showing first 8 rows)

# %% [markdown]
# ## Basic Operations

# %%
# sort
ddf.sort_values("trip_miles").head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # sort
# ----> 2 ddf.sort_values("trip_miles").head()
#
# File ~/miniforge3/envs/dask/lib/python3.11/site-packages/dask/dataframe/core.py:5344, in DataFrame.sort_values(self, by, npartitions, ascending, na_position, sort_function, sort_function_kwargs, **kwargs)
#    5312 """Sort the dataset by a single column.
#    5313
#    5314 Sorting a parallel dataset requires expensive shuffles and is generally
#    (...)
#    5340 >>> df2 = df.sort_values('x')  # doctest: +SKIP
#    5341 """
#    5342 from dask.dataframe.shuffle import sort_values
# -> 5344 return sort_values(
#    5345     self,
#    5346     by,
#    5347     ascending=ascending,
#    5348     npartitions=npartitions,
#    5349     na_position=na_position,
#    5350     sort_function=sort_function,
#    5351     sort_function_kwargs=sort_function_kwargs,
#    5352     **kwargs,
#    5353 )
#
# File ~/miniforge3/envs/dask/lib/python3.11/site-packages/dask/utils.py:265, in _deprecated_kwarg.<locals>._deprecated_kwarg.<locals>.wrapper(*args, **kwargs)
#     263         raise TypeError(msg)
#     264     kwargs[new_arg_name] = new_arg_value
# --> 265 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/dask/lib/python3.11/site-packages/dask/dataframe/shuffle.py:193, in sort_values(df, by, npartitions, shuffle_method, ascending, na_position, upsample, partition_size, sort_function, sort_function_kwargs)
#     191     divisions_ascending = divisions_ascending[0]
#     192 assert divisions_ascending is None or isinstance(divisions_ascending, bool)
# --> 193 divisions, _, _, presorted = _calculate_divisions(
#     194     df,
#     195     sort_by_col,
#     196     repartition,
#     197     npartitions,
#     198     upsample,
#     199     partition_size,
#     200     divisions_ascending,
#     201 )
#     203 if len(divisions) == 2:
#     204     return df.repartition(npartitions=1).map_partitions(
#     205         sort_function, **sort_kwargs
#     206     )
#
# File ~/miniforge3/envs/dask/lib/python3.11/site-packages/dask/dataframe/shuffle.py:61, in _calculate_divisions(df, partition_col, repartition, npartitions, upsample, partition_size, ascending)
#      58 maxes = partition_col.map_partitions(M.max)
#      60 try:
# ---> 61     divisions, sizes, mins, maxes = compute(divisions, sizes, mins, maxes)
#      62 except TypeError as e:
#      63     # When there are nulls and a column is non-numeric, a TypeError is sometimes raised as a result of
#      64     # 1) computing mins/maxes above, 2) every null being switched to NaN, and 3) NaN being a float.
#      65     # Also, Pandas ExtensionDtypes may cause TypeErrors when dealing with special nulls such as pd.NaT or pd.NA.
#      66     # If this happens, we hint the user about eliminating nulls beforehand.
#      67     if not is_numeric_dtype(partition_col.dtype):
#
# File ~/miniforge3/envs/dask/lib/python3.11/site-packages/dask/base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658     postcomputes.append(x.__dask_postcompute__())
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/miniforge3/envs/dask/lib/python3.11/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/miniforge3/envs/dask/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %% [markdown]
# This operation takes >20mins with Dask.

# %%
df.sort(daft.col("trip_miles"), desc=False).show(5)

# %% [markdown]
# This operation kills the kernel immediately with Daft.

# %%
# groupby

# %%
# join

# %%
# expressions

# %% [markdown]
# ## ML Workloads

# %% [markdown]
# ## Going Distributed
